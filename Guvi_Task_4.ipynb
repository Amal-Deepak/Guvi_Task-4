# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("/content/college_1.csv")
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# 1         Computer Science and Engineering       0
# 2         Computer Science and Engineering       0
# 3         Computer Science and Engineering       0
# 4         Computer Science and Engineering       0
# ..                                     ...     ...
# 79  Electronics and Electrical Engineering       0
# 80  Electronics and Electrical Engineering       0
# 81  Electronics and Electrical Engineering       0
# 82  Electronics and Electrical Engineering       0
# 83  Electronics and Electrical Engineering       0
#
# [84 rows x 7 columns]

# %%
df2=pd.read_csv("/content/college_2.csv")
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# 15             Rahul Raj K      -1          0      0                       0
# 16                 Guhan S      -1         72     35                      39
# 17            Suryarajan S      -1         63     31                       0
# 18          Narasimhan Y L      -1         -1      0                       0
# 19            Leelakrishna      -1          6      4                       0
# 20          PremsagarReddy      -1         20      0                       0
# 21               pradeeban      16         20     24                       0
# 22             santhoshini      -1         43      0                       0
# 23              MUKESH S M      -1         46      0                       0
# 24           P.GOVARDHANAN      -1         40      0                      -1
# 25            SHAIK DANISH      -1         43      0                       0
# 26               sridhar.s      -1         52      0                       0
# 27       Vimalesh Fernando      -1          0      0                       0
# 28           M.Karthikeyan      -1          0      4                       6
# 29               Abishak s      -1         55     35                       6
# 30           praveen raj j      24         -1      0                       0
# 31              AMARNATH D      -1         52     12                      -1
# 32                    bala      32         49      0                      -1
# 33                    XY Z      -1         20     -1                      -1
# 34               Hariharan      -1         -1     -1                       0
#
#     Previous Geekions  CodeKata Score  \
# 0               19400           19400
# 1               14150           14490
# 2                8790           10790
# 3               10040           10040
# 4                9150            9150
# 5                7210            8970
# 6                7250            8950
# 7                8650            8650
# 8                5180            8320
# 9                6170            8160
# 10               7470            8090
# 11               7670            8050
# 12               7340            8030
# 13               6400            7940
# 14               7170            7730
# 15               6280            7640
# 16               7310            7630
# 17               6710            7550
# 18               4800            6800
# 19               5300            6640
# 20               5290            6290
# 21               6060            6090
# 22               3910            5740
# 23               5200            5200
# 24               5050            5050
# 25               4050            4820
# 26               3860            4440
# 27               4170            4170
# 28               4020            4020
# 29               3220            3220
# 30               2380            2380
# 31               1890            1890
# 32               1720            1720
# 33                  0               0
# 34                  0               0
#
#                                    Department  Rising
# 0      Electronics and Electrical Engineering       0
# 1            Computer Science and Engineering     340
# 2            Computer Science and Engineering    2000
# 3   Electronics and Communication Engineering       0
# 4      Electronics and Electrical Engineering       0
# 5            Computer Science and Engineering    1760
# 6            Computer Science and Engineering    1700
# 7   Electronics and Communication Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 9      Electronics and Electrical Engineering    1990
# 10           Computer Science and Engineering     620
# 11           Computer Science and Engineering     380
# 12     Electronics and Electrical Engineering     690
# 13           Computer Science and Engineering    1540
# 14  Electronics and Communication Engineering     560
# 15           Computer Science and Engineering    1360
# 16  Electronics and Communication Engineering     320
# 17           Computer Science and Engineering     840
# 18           Computer Science and Engineering    2000
# 19           Computer Science and Engineering    1340
# 20           Computer Science and Engineering    1000
# 21           Computer Science and Engineering      30
# 22           Computer Science and Engineering    1830
# 23           Computer Science and Engineering       0
# 24  Electronics and Communication Engineering       0
# 25           Computer Science and Engineering     770
# 26           Computer Science and Engineering     580
# 27           Computer Science and Engineering       0
# 28           Computer Science and Engineering       0
# 29  Electronics and Communication Engineering       0
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0

# %%
#merging to csv files
df3=[df1,df2]
df=pd.concat(df3)
df
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 0       ASHOK KUMAR K     100          0     31                       9
# 1             Chandru       0         20      0                       0
# 2   Ganesh Ramkumar R      -1         55     24                       6
# 3     Bodipudi Harini      -1          0     35                      -1
# 4           VIINU V P      -1        100     24                      -1
# ..                ...     ...        ...    ...                     ...
# 30      praveen raj j      24         -1      0                       0
# 31         AMARNATH D      -1         52     12                      -1
# 32               bala      32         49      0                      -1
# 33               XY Z      -1         20     -1                      -1
# 34          Hariharan      -1         -1     -1                       0
#
#     Previous Geekions  CodeKata Score  \
# 0               19400           19400
# 1               14150           14490
# 2                8790           10790
# 3               10040           10040
# 4                9150            9150
# ..                ...             ...
# 30               2380            2380
# 31               1890            1890
# 32               1720            1720
# 33                  0               0
# 34                  0               0
#
#                                    Department  Rising
# 0      Electronics and Electrical Engineering       0
# 1            Computer Science and Engineering     340
# 2            Computer Science and Engineering    2000
# 3   Electronics and Communication Engineering       0
# 4      Electronics and Electrical Engineering       0
# ..                                        ...     ...
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
#
# [70 rows x 9 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
Exceeded_expectations=df[df["CodeKata Score"]>15000]
Exceeded_expectations.to_csv("Exceeded_expectations.csv")
Exceeded_expectations
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
# 0  ASHOK KUMAR K     100          0     31                       9
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
# 0              19400           19400  Electronics and Electrical Engineering
#
#    Rising
# 0       0
# 0       0

# %%
#or
'''Exceeded_expectations=df[df["CodeKata Score"]>15000]
codekata=pd.DataFrame(Exceeded_expectations)
codekata.to_csv("Exceeded_expectations.csv")'''
# Out:
# 'Exceeded_expectations=df[df["CodeKata Score"]>15000]\ncodekata=pd.DataFrame(Exceeded_expectations)\ncodekata.to_csv("Exceeded_expectations.csv")'

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations=df[df["CodeKata Score"].between(10000,15000)]
Reached_expectations.to_csv("Reached_expectations.csv")
Reached_expectations
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
#
#                                   Department  Rising
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_expectations=df[df["CodeKata Score"].between(7000,10000)]
Needs_expectations.to_csv("Needs_expectations.csv")
Needs_expectations
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# 15             Rahul Raj K      -1          0      0                       0
# 16                 Guhan S      -1         72     35                      39
# 17            Suryarajan S      -1         63     31                       0
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# 15             Rahul Raj K      -1          0      0                       0
# 16                 Guhan S      -1         72     35                      39
# 17            Suryarajan S      -1         63     31                       0
#
#     Previous Geekions  CodeKata Score  \
# 4                9150            9150
# 5                7210            8970
# 6                7250            8950
# 7                8650            8650
# 8                5180            8320
# 9                6170            8160
# 10               7470            8090
# 11               7670            8050
# 12               7340            8030
# 13               6400            7940
# 14               7170            7730
# 15               6280            7640
# 16               7310            7630
# 17               6710            7550
# 4                9150            9150
# 5                7210            8970
# 6                7250            8950
# 7                8650            8650
# 8                5180            8320
# 9                6170            8160
# 10               7470            8090
# 11               7670            8050
# 12               7340            8030
# 13               6400            7940
# 14               7170            7730
# 15               6280            7640
# 16               7310            7630
# 17               6710            7550
#
#                                    Department  Rising
# 4      Electronics and Electrical Engineering       0
# 5            Computer Science and Engineering    1760
# 6            Computer Science and Engineering    1700
# 7   Electronics and Communication Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 9      Electronics and Electrical Engineering    1990
# 10           Computer Science and Engineering     620
# 11           Computer Science and Engineering     380
# 12     Electronics and Electrical Engineering     690
# 13           Computer Science and Engineering    1540
# 14  Electronics and Communication Engineering     560
# 15           Computer Science and Engineering    1360
# 16  Electronics and Communication Engineering     320
# 17           Computer Science and Engineering     840
# 4      Electronics and Electrical Engineering       0
# 5            Computer Science and Engineering    1760
# 6            Computer Science and Engineering    1700
# 7   Electronics and Communication Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 9      Electronics and Electrical Engineering    1990
# 10           Computer Science and Engineering     620
# 11           Computer Science and Engineering     380
# 12     Electronics and Electrical Engineering     690
# 13           Computer Science and Engineering    1540
# 14  Electronics and Communication Engineering     560
# 15           Computer Science and Engineering    1360
# 16  Electronics and Communication Engineering     320
# 17           Computer Science and Engineering     840

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory=df[df["CodeKata Score"]<7000]
Unsatisfactory.to_csv("Unsatisfactory.csv")
Unsatisfactory
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 18     Narasimhan Y L      -1         -1      0                       0
# 19       Leelakrishna      -1          6      4                       0
# 20     PremsagarReddy      -1         20      0                       0
# 21          pradeeban      16         20     24                       0
# 22        santhoshini      -1         43      0                       0
# 23         MUKESH S M      -1         46      0                       0
# 24      P.GOVARDHANAN      -1         40      0                      -1
# 25       SHAIK DANISH      -1         43      0                       0
# 26          sridhar.s      -1         52      0                       0
# 27  Vimalesh Fernando      -1          0      0                       0
# 28      M.Karthikeyan      -1          0      4                       6
# 29          Abishak s      -1         55     35                       6
# 30      praveen raj j      24         -1      0                       0
# 31         AMARNATH D      -1         52     12                      -1
# 32               bala      32         49      0                      -1
# 33               XY Z      -1         20     -1                      -1
# 34          Hariharan      -1         -1     -1                       0
# 18     Narasimhan Y L      -1         -1      0                       0
# 19       Leelakrishna      -1          6      4                       0
# 20     PremsagarReddy      -1         20      0                       0
# 21          pradeeban      16         20     24                       0
# 22        santhoshini      -1         43      0                       0
# 23         MUKESH S M      -1         46      0                       0
# 24      P.GOVARDHANAN      -1         40      0                      -1
# 25       SHAIK DANISH      -1         43      0                       0
# 26          sridhar.s      -1         52      0                       0
# 27  Vimalesh Fernando      -1          0      0                       0
# 28      M.Karthikeyan      -1          0      4                       6
# 29          Abishak s      -1         55     35                       6
# 30      praveen raj j      24         -1      0                       0
# 31         AMARNATH D      -1         52     12                      -1
# 32               bala      32         49      0                      -1
# 33               XY Z      -1         20     -1                      -1
# 34          Hariharan      -1         -1     -1                       0
#
#     Previous Geekions  CodeKata Score  \
# 18               4800            6800
# 19               5300            6640
# 20               5290            6290
# 21               6060            6090
# 22               3910            5740
# 23               5200            5200
# 24               5050            5050
# 25               4050            4820
# 26               3860            4440
# 27               4170            4170
# 28               4020            4020
# 29               3220            3220
# 30               2380            2380
# 31               1890            1890
# 32               1720            1720
# 33                  0               0
# 34                  0               0
# 18               4800            6800
# 19               5300            6640
# 20               5290            6290
# 21               6060            6090
# 22               3910            5740
# 23               5200            5200
# 24               5050            5050
# 25               4050            4820
# 26               3860            4440
# 27               4170            4170
# 28               4020            4020
# 29               3220            3220
# 30               2380            2380
# 31               1890            1890
# 32               1720            1720
# 33                  0               0
# 34                  0               0
#
#                                    Department  Rising
# 18           Computer Science and Engineering    2000
# 19           Computer Science and Engineering    1340
# 20           Computer Science and Engineering    1000
# 21           Computer Science and Engineering      30
# 22           Computer Science and Engineering    1830
# 23           Computer Science and Engineering       0
# 24  Electronics and Communication Engineering       0
# 25           Computer Science and Engineering     770
# 26           Computer Science and Engineering     580
# 27           Computer Science and Engineering       0
# 28           Computer Science and Engineering       0
# 29  Electronics and Communication Engineering       0
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
# 18           Computer Science and Engineering    2000
# 19           Computer Science and Engineering    1340
# 20           Computer Science and Engineering    1000
# 21           Computer Science and Engineering      30
# 22           Computer Science and Engineering    1830
# 23           Computer Science and Engineering       0
# 24  Electronics and Communication Engineering       0
# 25           Computer Science and Engineering     770
# 26           Computer Science and Engineering     580
# 27           Computer Science and Engineering       0
# 28           Computer Science and Engineering       0
# 29  Electronics and Communication Engineering       0
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg1=df["Previous Geekions"].mean()
avg1
# Out:
# 6093.142857142857

# %%
avg2=df["CodeKata Score"].mean()
avg2
# Out:
# 6801.428571428572

# %%
mean=df[["Previous Geekions","CodeKata Score"]].mean()
mean
# Out:
# Previous Geekions    6093.142857
# CodeKata Score       6801.428571
# dtype: float64

# %%
plt.bar('Previous Geekions',avg1,width=0.6)
plt.bar('CodeKata Score',avg2,width=0.6)
plt.show()

# %% [markdown]
# ###### No of students participated

# %%
no_students=len(df['Name'])
no_students
# Out:
# 70

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
avgpy_course=df["python"].mean()
avgpy_course
# Out:
# 8.657142857142857

# %%
avg_compl=df["python"]/len(df["python"])
print("The average completion of python:",avg_compl)
print("The average completion of python:",avgpy_course)
# Out:
# The average completion of python: 0     1.428571
# 1     0.000000
# 2    -0.014286
# 3    -0.014286
# 4    -0.014286
#         ...
# 30    0.342857
# 31   -0.014286
# 32    0.457143
# 33   -0.014286
# 34   -0.014286
# Name: python, Length: 70, dtype: float64
# The average completion of python: 8.657142857142857

# %%
#or
avgmysql_course=df["mysql"].mean()
avgmysql_course
# Out:
# 13.657142857142857

# %%
avg_compl1=df["mysql"]/len(df["mysql"])
print("The average completion of mysql:",avg_compl1)
print("The average completion of mysql:",avgmysql_course)
# Out:
# The average completion of mysql: 0     0.442857
# 1     0.000000
# 2     0.342857
# 3     0.500000
# 4     0.342857
#         ...
# 30    0.000000
# 31    0.171429
# 32    0.000000
# 33   -0.014286
# 34   -0.014286
# Name: mysql, Length: 70, dtype: float64
# The average completion of mysql: 13.657142857142857

# %%
#or
avgpy_en_course=df["python_en"].mean()
avgpy_en_course
# Out:
# 29.65714285714286

# %%
avg_compl2=df["python_en"]/len(df["python_en"])
print("The average completion of python_en:",avg_compl2)
print("The average completion of python_en:",avgpy_en_course)
# Out:
# The average completion of python_en: 0     0.000000
# 1     0.285714
# 2     0.785714
# 3     0.000000
# 4     1.428571
#         ...
# 30   -0.014286
# 31    0.742857
# 32    0.700000
# 33    0.285714
# 34   -0.014286
# Name: python_en, Length: 70, dtype: float64
# The average completion of python_en: 29.65714285714286

# %%
#or
avgcomp_th_course=df["computational_thinking"].mean()
avgcomp_th_course
# Out:
# 2.2

# %%
avg_compl3=df["computational_thinking"]/len(df["computational_thinking"])
print("The average completion of python_en:",avg_compl3)
print("The average completion of python_en:",avgcomp_th_course)
# Out:
# The average completion of python_en: 0     0.128571
# 1     0.000000
# 2     0.085714
# 3    -0.014286
# 4    -0.014286
#         ...
# 30    0.000000
# 31   -0.014286
# 32   -0.014286
# 33   -0.014286
# 34    0.000000
# Name: computational_thinking, Length: 70, dtype: float64
# The average completion of python_en: 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_stars=df.nlargest(3,'Rising')
rising_stars
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 8           shifak N      58          0      0                       0
# 8           shifak N      58          0      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
#
#    Previous Geekions  CodeKata Score                              Department  \
# 8               5180            8320  Electronics and Electrical Engineering
# 8               5180            8320  Electronics and Electrical Engineering
# 2               8790           10790        Computer Science and Engineering
#
#    Rising
# 8    3140
# 8    3140
# 2    2000

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_stars=df.nlargest(3,'Previous Geekions')
shining_stars
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
# 0  ASHOK KUMAR K     100          0     31                       9
# 1        Chandru       0         20      0                       0
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
# 0              19400           19400  Electronics and Electrical Engineering
# 1              14150           14490        Computer Science and Engineering
#
#    Rising
# 0       0
# 0       0
# 1     340

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
fig=px.pie(df,names="Department",values="CodeKata Score",title="Department wise codekata performence")
fig.update_traces(textinfo='label+percent',textposition="outside",pull=0.2)#use hole for donut chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1c62ba6f-6aeb-4865-84cd-6860cc2df66e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c62ba6f-6aeb-4865-84cd-6860cc2df66e")) {                    Plotly.newPlot(                        "1c62ba6f-6aeb-4865-84cd-6860cc2df66e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Department=%{label}<br>CodeKata Score=%{value}<extra></extra>","labels":["Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering"],"legendgroup":"","name":"","showlegend":true,"values":[19400,14490,10790,10040,9150,8970,8950,8650,8320,8160,8090,8050,8030,7940,7730,7640,7630,7550,6800,6640,6290,6090,5740,5200,5050,4820,4440,4170,4020,3220,2380,1890,1720,0,0,19400,14490,10790,10040,9150,8970,8950,8650,8320,8160,8090,8050,8030,7940,7730,7640,7630,7550,6800,6640,6290,6090,5740,5200,5050,4820,4440,4170,4020,3220,2380,1890,1720,0,0],"type":"pie","pull":0.2,"textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ove ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df["Total_Marks"]=df["python"]+df["mysql"]+df["Previous Geekions"]+df["CodeKata Score"]+df["Rising"]+df["python_en"]+df["computational_thinking"]
df["Total_Marks"]
# Out:
# 0     38940
# 1     29000
# 2     21664
# 3     20113
# 4     18422
#       ...
# 30     4783
# 31     3842
# 32     3520
# 33       17
# 34       -3
# Name: Total_Marks, Length: 70, dtype: int64

# %%
df.groupby("Department").max()
# Out:
#                                                 Name  python  python_en  \
# Department
# Computer Science and Engineering           sridhar.s      24         78
# Electronics and Communication Engineering       bala      32         72
# Electronics and Electrical Engineering      shifak N     100        100
#
#                                            mysql  computational_thinking  \
# Department
# Computer Science and Engineering              62                       9
# Electronics and Communication Engineering    100                      39
# Electronics and Electrical Engineering        31                       9
#
#                                            Previous Geekions  CodeKata Score  \
# Department
# Computer Science and Engineering                       14150           14490
# Electronics and Communication Engineering              10040           10040
# Electronics and Electrical Engineering                 19400           19400
#
#                                            Rising  Total_Marks
# Department
# Computer Science and Engineering             2000        29000
# Electronics and Communication Engineering     560        20113
# Electronics and Electrical Engineering       3140        38940

# %%
color=["skyBlue","yellow","pink"]
df.groupby(["Department"]).max().plot(kind='pie', y='Total_Marks', autopct='%2.0f%%', labels=["sridhar.s","bala","shifak N"],title="Department wise toppers",
                                      colors=color,figsize=(9,9))
